# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import matplotlib.patches as mpatches

# %%
#!pip install pandas openpyxl

# %%
UV= pd.read_excel("TD-DFT_coronene.xlsx" , engine= "openpyxl")

# %%
UV
# Out:
#     Wavelength      fosc(D2)
# 0        384.9  2.000000e-09
# 1        353.9  5.900000e-08
# 2        284.7  3.000000e-09
# 3        283.0  8.572637e-01
# 4        280.1  1.000000e-09
# 5        226.6  1.600000e-08
# 6        210.4  3.190000e-07
# 7        208.8  3.927277e-03
# 8        201.6  6.696879e-02
# 9        199.9  1.163170e-01
# 10       199.7  4.000000e-08
# 11       192.6  2.909976e-03
# 12       187.7  4.470050e-01
# 13       184.3  3.190000e-07
# 14       182.3  9.035823e-02
# 15       181.7  2.277700e-05
# 16       181.0  1.448324e+00
# 17       179.1  1.021000e-06
# 18       176.7  9.600000e-08
# 19       174.3  1.761025e-03
# 20       174.0  1.874000e-06
# 21       170.9  4.480000e-07
# 22       169.8  1.360289e+00
# 23       168.1  4.217000e-06
# 24       167.4  9.795740e-04
# 25       167.3  3.300000e-08
# 26       167.1  3.133934e-01
# 27       166.3  1.710730e-04
# 28       154.1  7.900000e-08
# 29       151.2  4.261600e-03
# 30       150.1  5.200000e-08

# %%
plt.stem(UV["Wavelength"] , UV["fosc(D2)"] , markerfmt=(' ') , basefmt=(' '))
plt.xlim(left=(150,350))
plt.xticks(range(150, 351, 50)) # last no 50 is spacing in x axis 
plt.ylim(bottom=(0,1.6))
plt.yticks([i * 0.2 for i in range(0, 9)]) # set spacing between 2 points and range determine total numbers in y axis (0-1.6 = 9 numbers)
#plt.xlabel("Wavelength (nm)")
plt.ylabel("oscillator Strength")
#plt.title("Coronene (B3LYP-D3BJ)")
x = mpatches.Patch(color='white', label='Coronene') # to remove marker from label 
plt.legend(handles=[x], frameon=False)
plt.savefig("Coronene TDDFT plot B3LYP-D3BJ")
