# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import matplotlib.patches as mpatches

# %%
UV= pd.read_excel('TD-DFT BN-Coronene B3LYP.xlsx' , engine= 'openpyxl')

# %%
UV
# Out:
#         A         B
# 0   302.3  0.005212
# 1   288.7  0.001296
# 2   287.0  0.011197
# 3   265.5  0.317110
# 4   247.0  0.011714
# 5   243.6  0.000330
# 6   232.2  0.117193
# 7   229.6  0.101059
# 8   218.6  0.002409
# 9   212.9  0.051748
# 10  210.3  0.029744
# 11  210.1  0.054518
# 12  208.2  0.020130
# 13  206.9  0.017503
# 14  206.3  0.008737
# 15  206.1  0.007157
# 16  197.1  0.002168
# 17  195.8  0.059830
# 18  195.0  0.004580
# 19  192.3  0.066792
# 20  189.9  0.010446
# 21  187.1  0.000332
# 22  186.4  0.068068
# 23  185.6  0.040713
# 24  185.2  0.013728
# 25  184.0  0.253787
# 26  183.2  0.048748
# 27  182.0  0.065122
# 28  180.5  0.117927
# 29  177.6  0.001420
# 30  176.6  0.007190
# 31  173.7  0.026546
# 32  172.7  0.020740
# 33  171.3  0.139289
# 34  171.0  0.255787
# 35  167.8  0.002566
# 36  165.8  0.191695
# 37  165.4  0.000766
# 38  164.5  0.113878
# 39  162.9  0.049723
# 40  161.1  0.009474
# 41  159.8  0.026035
# 42  159.6  0.363426
# 43  157.3  0.015231
# ...

# %%
plt.stem(UV['A'] , UV['B'], markerfmt= (' '), basefmt= (' '))
plt.xlim(left=(150,600))
plt.xticks(range(150, 601, 50),  fontweight= 'bold') 
plt.ylim(bottom=(0,0.8))
plt.yticks([i * 0.2 for i in range(0, 5)],  fontweight= 'bold')
#plt.xlabel('Wavelength (nm)')
plt.ylabel('Oscillator Strength' , fontweight= 'bold')
#x = mpatches.Patch(color='white', label='BN-Coronene')
#plt.legend(handles=[x], frameon=False) 
for spine in plt.gca().spines.values():
    spine.set_linewidth(2.5)
    spine.set_color('black') 
plt.savefig('BN-Coronene TDDFT plot (B3LYP-D3BJ)')
