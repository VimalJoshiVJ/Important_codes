# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import matplotlib.patches as mpatches

# %%
UV= pd.read_excel('Benzene_ABS.xlsx' , engine= 'openpyxl')
UV
# Out:
#              Energy  TotalSpectrum
# 0      10807.078728       0.082317
# 1      10838.494655       0.082562
# 2      10869.910581       0.082807
# 3      10901.326508       0.083053
# 4      10932.742434       0.083298
# ...             ...            ...
# 5155  172756.180021       1.266930
# 5156  172787.595947       1.267159
# 5157  172819.011874       1.267387
# 5158  172850.427801       1.267616
# 5159  172881.843727       1.267844
#
# [5160 rows x 2 columns]

# %%
 # Convert wavenumber (cm^-1) to wavelength (nm)
UV['Wavelength'] = 1e7 / UV['Energy']

# Plot Absorption spectrum
#plt.figure(figsize=(8, 6))

plt.plot(UV['Wavelength'], UV['TotalSpectrum'], linewidth=2)

# Set wavelength range
plt.xlim(100, 400)
plt.ylim(bottom=(0))

# Labels
plt.xlabel('Wavelength (nm)', fontweight='bold', fontsize=13)
plt.ylabel('Intensity', fontweight='bold', fontsize=13)

# Bold tick labels
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')

# Make axis borders thicker
for spine in plt.gca().spines.values():
    spine.set_linewidth(2.5)
    spine.set_color('black')

plt.tight_layout()

# Save figure
plt.savefig('Benzene_Absorption_Spectrum.png', dpi=600, bbox_inches='tight')

plt.show()

# %%
#calculation is performed using LINES VOIGT, LINESW and INLINESW
